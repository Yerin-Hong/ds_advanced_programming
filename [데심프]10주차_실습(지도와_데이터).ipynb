# %% [markdown]
# # 🗺️ Folium 지도 시각화 심화 실습
#
# 이번 시간에는 **Folium**을 활용해 지도 시각화를 실습합니다.
#
# Folium은 **Python에서 지도를 시각화할 수 있는 라이브러리**로, HTML 기반의 인터랙티브(Interactive) 지도를 만들어 줍니다.
#
# > 🎯 학습 목표
# > - `folium.Map()`으로 **기본 지도 생성하기**
# > - `Marker`, `Icon`, `DivIcon`으로 **다양한 마커 표시**
# > - `zoom_start`, `location` 등 **지도 중심 설정 이해하기**
# > - 여러 지점을 **DataFrame으로 자동 반복 시각화**
#
# 💡 **중요 개념 정리**
# | 매개변수 | 설명 |
# |-----------|------|
# | `location` | [위도, 경도] 형식의 리스트로 지도 중심을 설정 |
# | `zoom_start` | 지도 확대 수준 (숫자가 클수록 더 가까이 확대됨) |
# | `icon` | 마커의 색상 및 모양 지정 |
# | `popup` | 마커 클릭 시 표시되는 텍스트 |
# | `DivIcon` | 지도 위에 **텍스트 라벨** 표시할 때 사용 |
#
# ---
#
# ## 1. 기본 지도 생성
#
# `folium.Map()`을 사용하여 지도 객체를 만들고 `location`과 `zoom_start`를 지정합니다.

# %%
# 필수 패키지 설치
# !pip install folium geokakao pandas --quiet

# 라이브러리 불러오기
import folium
import geokakao as gk
import pandas as pd

# %%
# 1) 지도 중심 좌표 설정
center = [37.57, 126.98]  # 서울 종로구 근처
print("지도 중심 좌표:", center)
# Out:
# 지도 중심 좌표: [37.57, 126.98]

# %%
# 2) 지도 객체 생성
# - location: 중심 좌표
# - zoom_start: 확대 레벨 (1=전세계, 13=도시 수준, 16=건물 수준)
map = folium.Map(location=center, zoom_start=13)

# %%
# 3) 출력 확인
print("folium.Map 객체 생성 완료! 아래에 지도가 표시됩니다 👇")
map
# Out:
# folium.Map 객체 생성 완료! 아래에 지도가 표시됩니다 👇
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_922fb548da1ba40238db68b52d603924 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_922fb548da1ba40238db68b52d603924&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_922fb548da1ba40238db68b52d603924 = L.map(
#                 &quot;map_922fb548da1ba40238db68b52d603924&quot;,
#                 {
#                     center: [37.57, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99abdf123f2ae9ec39268357b952a3cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99abdf123f2ae9ec39268357b952a3cb.addTo(map_922fb548da1ba40238db68b52d603924);
#
#
#             tile_layer_99abdf123f2ae9ec39268357b952a3cb.addTo(map_922fb548da1ba40238db68b52d603924);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. 주소를 중심으로 지도 표시하기
#
# 이번에는 **지명(주소)** 을 입력하고 이를 **위도/경도 좌표로 변환**하여 지도 중심으로 설정합니다.
#
# > 🧩 사용 함수
# > - `gk.convert_address_to_coordinates(주소)` → `[위도, 경도]`

# %%
# 주소 → 좌표로 변환
address = "서울 종로구 사직로 161"  # 경복궁
loc = gk.convert_address_to_coordinates(address)
print(f"주소 '{address}'의 변환 좌표:", loc)
# Out:
# 주소 '서울 종로구 사직로 161'의 변환 좌표: ('37.5759040910202', '126.976842133821')

# %%
# 지도 생성
map = folium.Map(location=loc, zoom_start=16)
print("지도 중심(위도, 경도):", map.location)
print("줌 레벨(zoom_start):", map.options['zoom'])
# Out:
# 지도 중심(위도, 경도): [37.5759040910202, 126.976842133821]
# 줌 레벨(zoom_start): 16

# %%
# 마커(Marker) 추가
# - location: 표시할 좌표
# - popup: 클릭 시 나올 정보
folium.Marker(location=loc, popup="경복궁").add_to(map)
print("마커 추가 완료 — popup='경복궁'")

map
# Out:
# 마커 추가 완료 — popup='경복궁'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c69a59b06f7d2a40863ae9807fe8244 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c69a59b06f7d2a40863ae9807fe8244&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c69a59b06f7d2a40863ae9807fe8244 = L.map(
#                 &quot;map_0c69a59b06f7d2a40863ae9807fe8244&quot;,
#                 {
#                     center: [37.5759040910202, 126.976842133821],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f40a1e4cf939df0c1e5ef60ec78a7cd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f40a1e4cf939df0c1e5ef60ec78a7cd8.addTo(map_0c69a59b06f7d2a40863ae9807fe8244);
#
#
#             var marker_4e6947754ac14f0f84502986efab2d3d = L.marker(
#                 [37.5759040910202, 126.976842133821],
#                 {
# }
#             ).addTo(map_0c69a59b06f7d2a40863ae9807fe8244);
#
#
#         var popup_0584ef08b58cf13ea7c32ced5a06846a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6abe66a8d870c7278aaf22417c85345e = $(`&lt;div id=&quot;html_6abe66a8d870c7278aaf22417c85345e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_0584ef08b58cf13ea7c32ced5a06846a.setContent(html_6abe66a8d870c7278aaf22417c85345e);
#
#
#
#         marker_4e6947754ac14f0f84502986efab2d3d.bindPopup(popup_0584ef08b58cf13ea7c32ced5a06846a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3. 마커 스타일 변경 및 텍스트 추가
#
# Folium은 단순 마커 외에도, `Icon` 옵션으로 색상/모양을 바꾸거나 `DivIcon`으로 텍스트를 표시할 수 있습니다.

# %%
# 강릉 경포해수욕장 좌표 구하기
address = "강원특별자치도 강릉시 창해로 514"
loc = gk.convert_address_to_coordinates(address)
print(f"'{address}' 의 좌표:", loc)
# Out:
# '강원특별자치도 강릉시 창해로 514' 의 좌표: ('37.8057701120176', '128.907481194757')

# %%
# 지도 생성
map = folium.Map(location=loc, zoom_start=13)
print(f"지도 중심 좌표: {map.location}, 확대레벨: {map.options['zoom']}")
# Out:
# 지도 중심 좌표: [37.8057701120176, 128.907481194757], 확대레벨: 13

# %%
# (1) 별모양 붉은 마커 추가
folium.Marker(
    location=loc,
    icon=folium.Icon(color="red", icon="star")
).add_to(map)
print("붉은 별 마커 추가 완료!")
# Out:
# 붉은 별 마커 추가 완료!

# %%
# (2) DivIcon으로 텍스트 추가
html_label = '<div style="font-size:12px; color:blue; background-color:rgba(255,255,255,0.6);"><b>경포해수욕장</b></div>'
folium.Marker(location=loc, icon=folium.DivIcon(html=html_label)).add_to(map)
print("텍스트 라벨 추가 완료!")

map
# Out:
# 텍스트 라벨 추가 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_217e8a416b083088caf263bbe9bdf3a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_217e8a416b083088caf263bbe9bdf3a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_217e8a416b083088caf263bbe9bdf3a2 = L.map(
#                 &quot;map_217e8a416b083088caf263bbe9bdf3a2&quot;,
#                 {
#                     center: [37.8057701120176, 128.907481194757],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71d3b65f4afba1e6ccc1a56daa956765 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71d3b65f4afba1e6ccc1a56daa956765.addTo(map_217e8a416b083088caf263bbe9bdf3a2);
#
#
#             var marker_85f23baff1f9514026c0f074cfacdd6f = L.marker(
#                 [37.8057701120176, 128.907481194757],
#                 {
# }
#             ).addTo(map_217e8a416b083088caf263bbe9bdf3a2);
#
#
#             var icon_adb24fc3ffbd5c46eb3d1c19ce915557 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_85f23baff1f9514026c0f074cfacdd6f.setIcon(icon_adb24fc3ffbd5c46eb3d1c19ce915557);
#
#
#             var marker_5d93c650f1a8f97d9362127de380fbc9 = L.marker(
#                 [37.8057701120176, 128.907481194757],
#                 {
# }
#             ).addTo(map_217e8a416b083088caf263bbe9bdf3a2);
#
#
#             var div_icon_6c70f1d822ad2df4238a3d8cf357a2a0 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:blue; background-color:rgba(255,255,255,0.6);\&quot;\u003e\u003cb\u003e\uacbd\ud3ec\ud574\uc218\uc695\uc7a5\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_5d93c650f1a8f97d9362127de380fbc9.setIcon(div_icon_6c70f1d822ad2df4238a3d8cf357a2a0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. DataFrame을 이용한 여러 관광지 표시
#
# 이번에는 **관광지 리스트를 DataFrame 형태로 저장**하고, `for` 반복문으로 여러 지점을 한 번에 지도 위에 표시해 보겠습니다.

# %%
# 제주 관광지 예시 데이터
names = ['용두암', '성산일출봉', '정방폭포', '중문관광단지', '한라산1100고지', '차귀도']
addr = [
    '제주시 용두암길 15',
    '서귀포시 성산읍 성산리',
    '서귀포시 동홍동 299-3',
    '서귀포시 중문동 2624-1',
    '서귀포시 색달동 산1-2',
    '제주시 한경면 고산리 산 117'
]

# %%
# DataFrame 생성
df = pd.DataFrame({'관광지명': names, '주소': addr})
print("초기 DataFrame 미리보기:")
print(df.head(), "\n")
# Out:
# 초기 DataFrame 미리보기:
#         관광지명               주소
# 0        용두암      제주시 용두암길 15
# 1      성산일출봉     서귀포시 성산읍 성산리
# 2       정방폭포   서귀포시 동홍동 299-3
# 3     중문관광단지  서귀포시 중문동 2624-1
# 4  한라산1100고지    서귀포시 색달동 산1-2

# %%
# 주소를 위도/경도로 변환하여 열 추가
gk.add_coordinates_to_dataframe(df, '주소')

# %%
# 좌표 데이터 확인
print("좌표 추가 후 DataFrame:")
print(df.head(), "\n")
# Out:
# 좌표 추가 후 DataFrame:
#         관광지명               주소   decimalLatitude  decimalLongitude
# 0        용두암      제주시 용두암길 15  33.5148035919525  126.511798046978
# 1      성산일출봉     서귀포시 성산읍 성산리  33.4641549468628  126.933094402743
# 2       정방폭포   서귀포시 동홍동 299-3  33.2450439717872  126.571611812583
# 3     중문관광단지  서귀포시 중문동 2624-1  33.2458014088806  126.420647253077
# 4  한라산1100고지    서귀포시 색달동 산1-2  33.3575245371214  126.462896523457

# %%
# 좌푯값을 숫자로 변환
df['decimalLatitude'] = pd.to_numeric(df['decimalLatitude'])
df['decimalLongitude'] = pd.to_numeric(df['decimalLongitude'])
print("좌표 데이터 타입 확인:")
print(df.dtypes[['decimalLatitude', 'decimalLongitude']], "\n")
# Out:
# 좌표 데이터 타입 확인:
# decimalLatitude     float64
# decimalLongitude    float64
# dtype: object

# %%
# 지도 중심 계산
center = [df['decimalLatitude'].mean(), df['decimalLongitude'].mean()]
print(f"지도 중심 좌표 (평균값): {center}")
# Out:
# 지도 중심 좌표 (평균값): [np.float64(33.35646904072083), np.float64(126.50771527972067)]

# %%
# 지도 생성
map = folium.Map(location=center, zoom_start=10)

# %%
# 각 관광지마다 마커 & 텍스트 표시
print("\n 지도에 마커 추가 중...")
for i in range(len(df)):
    loc = [df.loc[i, 'decimalLatitude'], df.loc[i, 'decimalLongitude']]
    folium.Marker(location=loc, icon=folium.Icon(color='red', icon='star')).add_to(map)
    html_label = f'<div style="font-size:12px; color:blue;"><b>{df.loc[i, "관광지명"]}</b></div>'
    folium.Marker(location=loc, icon=folium.DivIcon(html=html_label)).add_to(map)
    print(f"  - {df.loc[i, '관광지명']} 마커 추가 완료!")

print("\n 모든 관광지 마커 추가 완료!")
map
# Out:
#  지도에 마커 추가 중...
#   - 용두암 마커 추가 완료!
#   - 성산일출봉 마커 추가 완료!
#   - 정방폭포 마커 추가 완료!
#   - 중문관광단지 마커 추가 완료!
#   - 한라산1100고지 마커 추가 완료!
#   - 차귀도 마커 추가 완료!
#
#  모든 관광지 마커 추가 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a257f289a908aa3305255e8083f58739 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a257f289a908aa3305255e8083f58739&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a257f289a908aa3305255e8083f58739 = L.map(
#                 &quot;map_a257f289a908aa3305255e8083f58739&quot;,
#                 {
#                     center: [33.35646904072083, 126.50771527972067],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77b8b32445f5046097a48f5b9cd2b3ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77b8b32445f5046097a48f5b9cd2b3ba.addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var marker_cee1212187d442a11355490a397ae105 = L.marker(
#                 [33.5148035919525, 126.511798046978],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var icon_ec582edbe545c092cc7fae73b731ae86 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_cee1212187d442a11355490a397ae105.setIcon(icon_ec582edbe545c092cc7fae73b731ae86);
#
#
#             var marker_366d7bd5fecf0d6d4ef6e713457e4c4b = L.marker(
#                 [33.5148035919525, 126.511798046978],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var div_icon_936889cc85003192d6947f4eecf5a0b3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:blue;\&quot;\u003e\u003cb\u003e\uc6a9\ub450\uc554\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_366d7bd5fecf0d6d4ef6e713457e4c4b.setIcon(div_icon_936889cc85003192d6947f4eecf5a0b3);
#
#
#             var marker_0e9992abae12ea2663de9aa5bf63d559 = L.marker(
#                 [33.4641549468628, 126.933094402743],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var icon_38c158bd169c381e6c465587c98d6b12 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_0e9992abae12ea2663de9aa5bf63d559.setIcon(icon_38c158bd169c381e6c465587c98d6b12);
#
#
#             var marker_7bdeac3ef40181c57ccf26d2279065ca = L.marker(
#                 [33.4641549468628, 126.933094402743],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var div_icon_3083530170353bede8ecd3ae1898c76d = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:blue;\&quot;\u003e\u003cb\u003e\uc131\uc0b0\uc77c\ucd9c\ubd09\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_7bdeac3ef40181c57ccf26d2279065ca.setIcon(div_icon_3083530170353bede8ecd3ae1898c76d);
#
#
#             var marker_001dea3181889b551436f55aaecb4e07 = L.marker(
#                 [33.2450439717872, 126.571611812583],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var icon_4d892fd00a99698a781ad5f311fe3b6c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_001dea3181889b551436f55aaecb4e07.setIcon(icon_4d892fd00a99698a781ad5f311fe3b6c);
#
#
#             var marker_de9105b4c0fd2e1876119cc0ea4ab975 = L.marker(
#                 [33.2450439717872, 126.571611812583],
#                 {
# }
#             ).addTo(map_a257f289a908aa3305255e8083f58739);
#
#
#             var div_icon_c58d9b3182b6ee7e38e83e67d4dba7d5 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:12px; color:blue;\&quot;\u003e\u003cb\u003e\uc815\ubc29\ud3ed\ud3ec\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });

# %%
# 관광지 데이터 확인용 요약
print("총 관광지 개수:", len(df))
print("\n관광지명 리스트:", list(df['관광지명']))
print("\n위도 평균:", round(df['decimalLatitude'].mean(), 5))
print("경도 평균:", round(df['decimalLongitude'].mean(), 5))
# Out:
# 총 관광지 개수: 6
#
# 관광지명 리스트: ['용두암', '성산일출봉', '정방폭포', '중문관광단지', '한라산1100고지', '차귀도']
#
# 위도 평균: 33.35647
# 경도 평균: 126.50772

# %% [markdown]
# # 💡 Folium 지도 시각화 응용 가이드 (심화 이론 정리)
#
# 이 섹션에서는 Folium을 활용할 때 알아두면 좋은 **고급 설정 옵션과 시각화 확장 아이디어**를 정리합니다.
# 학생들은 이를 바탕으로 지도를 자신만의 스타일로 꾸미거나, 데이터 기반 시각화를 심화시킬 수 있습니다.
#
# ---
#
# ## 1️⃣ 지도(Map) 객체 확장 옵션
#
# Folium의 `folium.Map()`은 단순한 지도 객체를 생성하는 것 외에도
# 다양한 속성을 통해 지도의 시각적 스타일과 조작성을 개선할 수 있습니다.
#
# | 옵션명 | 설명 |
# |--------|------|
# | `location` | 지도 중심 좌표로 `[위도, 경도]` 형태로 지정합니다. |
# | `zoom_start` | 초기 확대 수준 (1 = 전 세계, 18 = 건물 수준). |
# | `tiles` | 지도 배경 스타일을 선택합니다.<br>예: `"OpenStreetMap"`, `"CartoDB positron"`, `"CartoDB dark_matter"` |
# | `control_scale` | 지도의 하단에 **거리 스케일바**를 표시할지 여부를 결정합니다. |
# | `min_zoom / max_zoom` | 사용자가 확대·축소 가능한 최소/최대 범위를 제한합니다. |
# | `attr` | 커스텀 지도 타일을 사용할 때 저작권 표시를 추가할 수 있습니다. |
#
# > 💡 `tiles` 속성은 시각적인 느낌을 완전히 바꿀 수 있으므로,
# > 프로젝트 목적(관광, 기상, 통계 등)에 맞는 스타일을 선택하는 것이 중요합니다.
#
# ---

# %%
# 🌍 Folium 기본 지도 설정 예제
import folium

# 1️⃣ 지도 중심 좌표 지정 — 서울 종로구 근처
center = [37.57, 126.98]
print("지도 중심 좌표:", center)

# 2️⃣ 다양한 옵션과 스타일 적용
map1 = folium.Map(
    location=center,                # 중심 좌표
    zoom_start=13,                  # 확대 수준 (1~18)
    tiles="CartoDB positron",       # 지도 스타일
    control_scale=True,             # 하단 스케일바 표시
    min_zoom=8,                     # 최소 확대 수준 제한
    max_zoom=17                     # 최대 확대 수준 제한
)
print("Folium 지도 객체 생성 완료!")

# 3️⃣ 지도 출력
map1
# Out:
# 지도 중심 좌표: [37.57, 126.98]
# Folium 지도 객체 생성 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0146228bd5d8d92c9c08da44dc90bf36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0146228bd5d8d92c9c08da44dc90bf36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0146228bd5d8d92c9c08da44dc90bf36 = L.map(
#                 &quot;map_0146228bd5d8d92c9c08da44dc90bf36&quot;,
#                 {
#                     center: [37.57, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0146228bd5d8d92c9c08da44dc90bf36);
#
#
#
#
#
#             var tile_layer_02e48ba004c38190602501ab0c92745c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 8,
#   &quot;maxZoom&quot;: 17,
#   &quot;maxNativeZoom&quot;: 17,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02e48ba004c38190602501ab0c92745c.addTo(map_0146228bd5d8d92c9c08da44dc90bf36);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ## 2️⃣ 마커(Marker) 관련 속성 및 커스터마이징
#
# Folium의 `Marker()`는 지도 위 특정 지점을 표시하는 가장 기본적인 객체입니다.
# 이 마커에 다양한 속성을 지정하여 색상, 모양, 아이콘을 자유롭게 변경할 수 있습니다.
#
# | 속성명 | 설명 |
# |--------|------|
# | `location` | 마커가 표시될 좌표 `[위도, 경도]` |
# | `popup` | 마커 클릭 시 표시되는 텍스트 또는 HTML |
# | `tooltip` | 마우스 커서를 올렸을 때 잠깐 표시되는 설명 텍스트 |
# | `icon` | `folium.Icon()` 객체로 마커의 색상·모양을 지정 |
# | `draggable` | `True`로 설정 시 사용자가 마커를 드래그할 수 있음 |
#
# ### 🧩 `Icon()` 객체 주요 속성
# | 속성명 | 설명 |
# |--------|------|
# | `color` | 마커 색상 지정 (`'red'`, `'blue'`, `'green'`, `'purple'` 등) |
# | `icon` | 아이콘 형태 (`'star'`, `'flag'`, `'home'`, `'camera'` 등) |
# | `prefix` | `'fa'`를 지정하면 Font Awesome 아이콘 세트를 사용 가능 |
# | `icon_color` | 아이콘 내부의 색상 지정 (기본값은 흰색) |
#
# > 💡 Folium의 기본 아이콘 외에도 Font Awesome 아이콘을 자유롭게 사용할 수 있습니다.
#
# ---

# %%
# 📍 Folium Marker 응용 예제
import folium

# 서울시청 좌표
loc = [37.5665, 126.9780]

# 지도 생성
map2 = folium.Map(location=loc, zoom_start=15)
print("지도 중심:", map2.location)

# 1️⃣ 기본 마커
folium.Marker(
    location=loc,
    popup="서울시청 (기본 마커)"
).add_to(map2)

# 2️⃣ 색상 + 아이콘 커스터마이징
folium.Marker(
    location=[37.5668, 126.9785],
    popup="보라색 집 아이콘",
    icon=folium.Icon(color="purple", icon="home", prefix="fa")
).add_to(map2)

# 3️⃣ 드래그 가능한 마커
folium.Marker(
    location=[37.5671, 126.9790],
    popup="이 마커는 드래그 가능!",
    draggable=True,
    icon=folium.Icon(color="green", icon="flag")
).add_to(map2)

print("총 3개의 마커가 추가되었습니다!")
map2
# Out:
# 지도 중심: [37.5665, 126.978]
# 총 3개의 마커가 추가되었습니다!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9f6d385e06b44fd7f441ae799e07603 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9f6d385e06b44fd7f441ae799e07603&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9f6d385e06b44fd7f441ae799e07603 = L.map(
#                 &quot;map_e9f6d385e06b44fd7f441ae799e07603&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5adf6e24ac720b0d4f28109767e1c2db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5adf6e24ac720b0d4f28109767e1c2db.addTo(map_e9f6d385e06b44fd7f441ae799e07603);
#
#
#             var marker_f444c85afba15284576f2a97bc381cf1 = L.marker(
#                 [37.5665, 126.978],
#                 {
# }
#             ).addTo(map_e9f6d385e06b44fd7f441ae799e07603);
#
#
#         var popup_ebb483b8fcf7a6ceecf2abf113406a3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b63d0c4041092ab724442b52ed41d70 = $(`&lt;div id=&quot;html_3b63d0c4041092ab724442b52ed41d70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청 (기본 마커)&lt;/div&gt;`)[0];
#                 popup_ebb483b8fcf7a6ceecf2abf113406a3b.setContent(html_3b63d0c4041092ab724442b52ed41d70);
#
#
#
#         marker_f444c85afba15284576f2a97bc381cf1.bindPopup(popup_ebb483b8fcf7a6ceecf2abf113406a3b)
#         ;
#
#
#
#
#             var marker_fd64256af81b05d05beaf83a0243deec = L.marker(
#                 [37.5668, 126.9785],
#                 {
# }
#             ).addTo(map_e9f6d385e06b44fd7f441ae799e07603);
#
#
#             var icon_47ffb10be83376142338d046a35523de = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b19617e9f04fb2a3c488605cedd2405e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b34a060e329f8f1f68cd2ec77e345cdb = $(`&lt;div id=&quot;html_b34a060e329f8f1f68cd2ec77e345cdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;보라색 집 아이콘&lt;/div&gt;`)[0];
#                 popup_b19617e9f04fb2a3c488605cedd2405e.setContent(html_b34a060e329f8f1f68cd2ec77e345cdb);
#
#
#
#         marker_fd64256af81b05d05beaf83a0243deec.bindPopup(popup_b19617e9f04fb2a3c488605cedd2405e)
#         ;
#
#
#
#
#                 marker_fd64256af81b05d05beaf83a0243deec.setIcon(icon_47ffb10be83376142338d046a35523de);
#
#
#             var marker_8bce5cf36507d3c5b990cb0784b1045d = L.marker(
#                 [37.5671, 126.979],
#                 {
#   &quot;draggable&quot;: true,
#   &quot;autoPan&quot;: true,
# }
#             ).addTo(map_e9f6d385e06b44fd7f441ae799e07603);
#
#
#             var icon_c914da5c7b3095204606c2d487aba68a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d09867b644fc46cd05a4cb2dfabd3f1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38897a1facf77643d92bc653eb9e3d73 = $(`&lt;div id=&quot;html_38897a1facf77643d92bc653eb9e3d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이 마커는 드래그 가능!&lt;/div&gt;`)[0];
#                 popup_d09867b644fc46cd05a4cb2dfabd3f1f.setContent(html_38897a1facf77643d92bc653eb9e3d73);
#
#
#
#         marker_8bce5cf36507d3c5b990cb0784b1045d.bindPopup(popup_d09867b644fc46cd05a4cb2dfabd3f1f)
#         ;
#
#
#
#
#                 marker_8bce5cf36507d3c5b990cb0784b1045d.setIcon(icon_c914da5c7b3095204606c2d487aba68a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ## 3️⃣ 텍스트 라벨(DivIcon) 활용
#
# `DivIcon`은 지도 위에 **글자, HTML, 이모티콘, 스타일이 적용된 요소**를 직접 표시할 수 있는 강력한 기능입니다.
# HTML을 이용해 글자 크기, 색상, 배경 등을 자유롭게 꾸밀 수 있습니다.
#
# | 속성명 | 설명 |
# |--------|------|
# | `html` | 실제로 표시할 HTML 코드 문자열 |
# | `icon_anchor` | 텍스트 위치 기준점을 지정 (`(x, y)` 좌표) |
# | `class_name` | CSS 클래스를 지정할 수 있음 (기본값: `"empty"`) |
#
# ### ✨ 주요 스타일 속성 (HTML 내 `style` 사용)
# | 속성 | 설명 |
# |------|------|
# | `font-size` | 글자 크기 지정 (예: `14px`, `18px`) |
# | `color` | 글자 색상 지정 (예: `red`, `#0044ff`) |
# | `background-color` | 배경색 및 투명도 조절 (예: `rgba(255,255,255,0.6)`) |
# | `border-radius` | 텍스트 상자 모서리를 둥글게 만듦 |
# | `width / height` | 텍스트 상자의 크기 조정 |
# | `text-align` | 텍스트 정렬 (`left`, `center`, `right`) |
#
# > 💡 `DivIcon`을 이용하면 지도 위에 지명, 수치값, 태그 등
# > **데이터 기반 텍스트 라벨링(labeling)** 을 시각적으로 표현할 수 있습니다.
#
# ---

# %%
# 지도 위에 HTML 라벨 표시하기 (DivIcon)
import folium

# 경복궁 좌표
loc = [37.5796, 126.9770]

# 지도 생성
map3 = folium.Map(location=loc, zoom_start=16)

# 텍스트용 HTML 블록 정의
html_label = '''
<div style="
    font-size:16px;
    color:#0044ff;
    background-color:rgba(255,255,255,0.8);
    border-radius:5px;
    text-align:center;
    width:120px;
    padding:3px;">
<b>경복궁</b>
</div>
'''

# DivIcon 사용하여 지도에 추가
folium.Marker(
    location=loc,
    icon=folium.DivIcon(html=html_label)
).add_to(map3)

print("HTML 스타일 라벨 추가 완료!")
map3
# Out:
# HTML 스타일 라벨 추가 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04e89f783b783414f58f43c3ceb16c04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04e89f783b783414f58f43c3ceb16c04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04e89f783b783414f58f43c3ceb16c04 = L.map(
#                 &quot;map_04e89f783b783414f58f43c3ceb16c04&quot;,
#                 {
#                     center: [37.5796, 126.977],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76ec1d414ff5a48a45516c3a6c10348e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76ec1d414ff5a48a45516c3a6c10348e.addTo(map_04e89f783b783414f58f43c3ceb16c04);
#
#
#             var marker_f93f118f88a9f5453a4ba9fb7d48c3c1 = L.marker(
#                 [37.5796, 126.977],
#                 {
# }
#             ).addTo(map_04e89f783b783414f58f43c3ceb16c04);
#
#
#             var div_icon_aa0f64940b6b1ca30e5ba863f06f2564 = L.divIcon({
#   &quot;html&quot;: &quot;\n\u003cdiv style=\&quot;\n    font-size:16px;\n    color:#0044ff;\n    background-color:rgba(255,255,255,0.8);\n    border-radius:5px;\n    text-align:center;\n    width:120px;\n    padding:3px;\&quot;\u003e\n\u003cb\u003e\uacbd\ubcf5\uad81\u003c/b\u003e\n\u003c/div\u003e\n&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_f93f118f88a9f5453a4ba9fb7d48c3c1.setIcon(div_icon_aa0f64940b6b1ca30e5ba863f06f2564);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ## 4️⃣ 반복문(for)을 이용한 다중 마커 표시
#
# `for` 반복문과 DataFrame을 조합하면
# 수십~수백 개의 지점을 **자동으로 지도에 표시**할 수 있습니다.
#
# | 개념 | 설명 |
# |------|------|
# | `df.iterrows()` | DataFrame의 각 행(row)을 반복 처리할 때 사용 |
# | `iloc` / `loc` | 인덱스 또는 라벨 기반으로 개별 좌표를 참조 |
# | `add_to(map)` | 만들어진 마커를 현재 지도 객체에 추가 |
#
# > 💡 `for`문 내에서 조건문(`if`)을 함께 사용하면,
# > 예를 들어 특정 조건(`관객 수 > 100만`)에만 다른 색상의 마커를 표시하는 것도 가능합니다.
#
# ---

# %%
# 🔁 반복문을 이용한 여러 지점 마커 표시
import folium
import pandas as pd

# 제주 관광지 예시 데이터
data = {
    "이름": ["용두암", "성산일출봉", "정방폭포", "중문관광단지", "한라산1100고지", "차귀도"],
    "위도": [33.5163, 33.4583, 33.2458, 33.2554, 33.3595, 33.3040],
    "경도": [126.5110, 126.9424, 126.5623, 126.4122, 126.5129, 126.1621]
}
df = pd.DataFrame(data)
print("관광지 데이터프레임 미리보기:")
print(df.head(), "\n")

# 지도 중심 계산
center = [df["위도"].mean(), df["경도"].mean()]
print("지도 중심:", center)

# 지도 객체 생성
map4 = folium.Map(location=center, zoom_start=10)

# 반복문을 이용해 마커 추가
for i, row in df.iterrows():
    loc = [row["위도"], row["경도"]]
    name = row["이름"]

    # 마커 색상 변경 규칙 (짝수행/홀수행)
    color = "red" if i % 2 == 0 else "blue"

    folium.Marker(
        location=loc,
        popup=f"{name} (색상: {color})",
        icon=folium.Icon(color=color, icon="star")
    ).add_to(map4)

print("모든 관광지 마커 추가 완료!")
map4
# Out:
# 관광지 데이터프레임 미리보기:
#           이름       위도        경도
# 0        용두암  33.5163  126.5110
# 1      성산일출봉  33.4583  126.9424
# 2       정방폭포  33.2458  126.5623
# 3     중문관광단지  33.2554  126.4122
# 4  한라산1100고지  33.3595  126.5129
#
# 지도 중심: [np.float64(33.356550000000006), np.float64(126.51715)]
# 모든 관광지 마커 추가 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88d8a46e093d0041b5ecec5b533bc61c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88d8a46e093d0041b5ecec5b533bc61c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88d8a46e093d0041b5ecec5b533bc61c = L.map(
#                 &quot;map_88d8a46e093d0041b5ecec5b533bc61c&quot;,
#                 {
#                     center: [33.356550000000006, 126.51715],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd6acf4019220aa6f28fa6650938195a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd6acf4019220aa6f28fa6650938195a.addTo(map_88d8a46e093d0041b5ecec5b533bc61c);
#
#
#             var marker_db3fab47dd57f7c0deca89b9b8d45098 = L.marker(
#                 [33.5163, 126.511],
#                 {
# }
#             ).addTo(map_88d8a46e093d0041b5ecec5b533bc61c);
#
#
#             var icon_7517f87834a73212fa2c0871114104a6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3fd3b378d43a9c8b59585edcf6d8893d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f76b551184ce594301dfd3864fea3e9f = $(`&lt;div id=&quot;html_f76b551184ce594301dfd3864fea3e9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용두암 (색상: red)&lt;/div&gt;`)[0];
#                 popup_3fd3b378d43a9c8b59585edcf6d8893d.setContent(html_f76b551184ce594301dfd3864fea3e9f);
#
#
#
#         marker_db3fab47dd57f7c0deca89b9b8d45098.bindPopup(popup_3fd3b378d43a9c8b59585edcf6d8893d)
#         ;
#
#
#
#
#                 marker_db3fab47dd57f7c0deca89b9b8d45098.setIcon(icon_7517f87834a73212fa2c0871114104a6);
#
#
#             var marker_0c17d74870cc75c59783c7548f296f9f = L.marker(
#                 [33.4583, 126.9424],
#                 {
# }
#             ).addTo(map_88d8a46e093d0041b5ecec5b533bc61c);
#
#
#             var icon_0cca44f95de1112e4c8ed400989888c0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_307610f5d2124be17cd2282d655fdb72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17c27f845012907e0742b20c82db02fc = $(`&lt;div id=&quot;html_17c27f845012907e0742b20c82db02fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성산일출봉 (색상: blue)&lt;/div&gt;`)[0];
#                 popup_307610f5d2124be17cd2282d655fdb72.setContent(html_17c27f845012907e0742b20c82db02fc);
#
#
#
#         marker_0c17d74870cc75c59783c7548f296f9f.bindPopup(popup_307610f5d2124be17cd2282d655fdb72)
#         ;
#
#
#
#
#                 marker_0c17d74870cc75c59783c7548f296f9f.setIcon(icon_0cca44f95de1112e4c8ed400989888c0);
#
#
#             var marker_b3078df706518268c80d39b82645b0f3 = L.marker(
#                 [33.2458, 126.5623],
#                 {
# }
#             ).addTo(map_88d8a46e093d0041b5ecec5b533bc61c);
#
#
#             var icon_9f5c733bcacf1eb7b78dca8ff618417b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30a27f90a645e923a31a1ddf2688497e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9e4bf77603fd2714a89d52547d1ae8a = $(`&lt;div id=&quot;html_b9e4bf77603fd2714a89d52547d1ae8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정방폭포 (색상: red)&lt;/div&gt;`)[0];
#                 popup_30a27f90a645e923a31a1ddf2688497e.setContent(html_b9e4bf77603fd2714a89d52547d1ae8a);
#
#
#
#         marker_b3078df706518268c80d39b82645b0f3.bindPopup(popup_30a27f90a645e923a31a1ddf2688497e)
#         ;
#
#
#
#
#                 marker_b3078df706518268c80d39b82645b0f3.setIcon(icon_9f5c733bcacf1eb7b78dca8ff618417b);
#
#
#             var marker_8cf6dc072887143887cb49d9e4481d43 =

# %% [markdown]
# ---
#
# ## 5️⃣ CircleMarker로 데이터의 “크기” 표현
#
# `CircleMarker`는 원의 반지름(radius)을 수치 데이터에 비례하도록 설정할 수 있어,
# **값의 크기 시각화(예: 인구수, 매출액, 방문자 수)** 에 매우 유용합니다.
#
# | 속성명 | 설명 |
# |--------|------|
# | `radius` | 원의 반지름 (데이터 값에 비례시킬 수 있음) |
# | `color` | 원의 테두리 색상 |
# | `fill` | 내부 색상 채움 여부 (기본값: `True`) |
# | `fill_color` | 내부 색상 지정 |
# | `fill_opacity` | 내부 색상의 투명도 (0~1 사이 값) |
# | `stroke` | 테두리선 표시 여부 |
#
# > 💡 **데이터 크기를 시각화할 때**
# > 단순히 수치를 직접 반지름으로 쓰면 원이 너무 커지므로,
# > 보통 `radius = 값 ** 0.5` 또는 `값 / 일정 상수` 형태로 스케일링합니다.
#
# ---

# %%
# 🧮 CircleMarker로 값의 크기를 반영한 지도 만들기
import folium
import pandas as pd

# 풍속 데이터 예시 (간단한 6개 지점)
df = pd.DataFrame({
    "도시": ["서울", "부산", "대구", "광주", "인천", "춘천"],
    "위도": [37.57, 35.17, 35.87, 35.16, 37.45, 37.87],
    "경도": [126.98, 129.07, 128.60, 126.85, 126.70, 127.73],
    "풍속": [10.5, 8.2, 12.8, 9.0, 6.3, 15.0]
})
print("풍속 데이터:")
print(df, "\n")

# 지도 중심 계산
center = [df["위도"].mean(), df["경도"].mean()]
print("지도 중심:", center)

# 지도 생성
map5 = folium.Map(location=center, zoom_start=6)

# 각 도시의 풍속에 비례한 원형 표시
for i, row in df.iterrows():
    loc = [row["위도"], row["경도"]]
    radius = row["풍속"] ** 0.8  # 값의 크기를 조정하여 원 크기 조절
    folium.CircleMarker(
        location=loc,
        radius=radius,          # 원의 반지름
        color="red",            # 테두리 색
        fill=True,              # 내부 색 채움
        fill_color="red",
        fill_opacity=0.5,       # 투명도
        popup=f"{row['도시']} 풍속: {row['풍속']} m/s"
    ).add_to(map5)
    print(f"{row['도시']} 마커 추가 (풍속={row['풍속']})")

print("모든 CircleMarker 추가 완료!")
map5
# Out:
# 풍속 데이터:
#    도시     위도      경도    풍속
# 0  서울  37.57  126.98  10.5
# 1  부산  35.17  129.07   8.2
# 2  대구  35.87  128.60  12.8
# 3  광주  35.16  126.85   9.0
# 4  인천  37.45  126.70   6.3
# 5  춘천  37.87  127.73  15.0
#
# 지도 중심: [np.float64(36.51500000000001), np.float64(127.65500000000002)]
# 서울 마커 추가 (풍속=10.5)
# 부산 마커 추가 (풍속=8.2)
# 대구 마커 추가 (풍속=12.8)
# 광주 마커 추가 (풍속=9.0)
# 인천 마커 추가 (풍속=6.3)
# 춘천 마커 추가 (풍속=15.0)
# 모든 CircleMarker 추가 완료!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de530b1c08915e4b3c406328bc797580 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de530b1c08915e4b3c406328bc797580&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de530b1c08915e4b3c406328bc797580 = L.map(
#                 &quot;map_de530b1c08915e4b3c406328bc797580&quot;,
#                 {
#                     center: [36.51500000000001, 127.65500000000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a39eecc9d772883b7c07044e9a197d94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a39eecc9d772883b7c07044e9a197d94.addTo(map_de530b1c08915e4b3c406328bc797580);
#
#
#             var circle_marker_cf4edd6fc09a7ebceaab8c573baef76a = L.circleMarker(
#                 [37.57, 126.98],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.560719033605906, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de530b1c08915e4b3c406328bc797580);
#
#
#         var popup_5ed1fa4e11e19d81dcd7e737b8a9ad0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_815cfd5c5fc6a52db1934fe3bf71173b = $(`&lt;div id=&quot;html_815cfd5c5fc6a52db1934fe3bf71173b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 풍속: 10.5 m/s&lt;/div&gt;`)[0];
#                 popup_5ed1fa4e11e19d81dcd7e737b8a9ad0c.setContent(html_815cfd5c5fc6a52db1934fe3bf71173b);
#
#
#
#         circle_marker_cf4edd6fc09a7ebceaab8c573baef76a.bindPopup(popup_5ed1fa4e11e19d81dcd7e737b8a9ad0c)
#         ;
#
#
#
#
#             var circle_marker_91a18f8562622803401e3fe43774ed7e = L.circleMarker(
#                 [35.17, 129.07],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.383330977671217, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de530b1c08915e4b3c406328bc797580);
#
#
#         var popup_3b52daa93c860ce7a3a69a4766dcf00e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d5a3a0865a34b9280ba1a9cca72c0a4 = $(`&lt;div id=&quot;html_6d5a3a0865a34b9280ba1a9cca72c0a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산 풍속: 8.2 m/s&lt;/div&gt;`)[0];
#                 popup_3b52daa93c860ce7a3a69a4766dcf00e.setContent(html_6d5a3a0865a34b9280ba1a9cca72c0a4);
#
#
#
#         circle_marker_91a18f8562622803401e3fe43774ed7e.bindPopup(popup_3b52daa93c860ce7a3a69a4766dcf00e)
#         ;
#
#
#
#
#             var circle_marker_20f752f47169f07a0f46b04688465acf = L.circleMarker(
#                 [35.87, 128.6],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.687196377481161, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de530b1c08915e4b3c406328bc797580);
#
#
#         var popup_54b0b245f797430fa24ecb17326e6298 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f478e32c0cde870db8842d8cd39dc92a = $(`&lt;div id=&quot;html_f478e32c0cde870db8842d8cd39dc92a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대구 풍속: 12.8 m/s&lt;/div&gt;`)[0];
#                 popup_54b0b245f797430fa24ecb17326e6298.setContent(html_f478e32c0cde870db8842d8cd39dc92a);
#
#
#
#         circle_marker_20f752f47169f07a0f46b04688465acf.bindPopup(popup_54b0b245f797430fa24ecb17326e6298)
#         ;
#
#
#
#
#             var circle_marker_27be74

# %% [markdown]
# ---
#
# ## 6️⃣ 시각적 통일성과 해석력 높이기
#
# 1. **지도 색상 팔레트 유지**
#    - 동일한 범주 데이터(예: 도시, 지역)는 같은 색상을 유지합니다.
# 2. **글자 크기(font-size) 통일**
#    - 지도 내 모든 라벨은 12~14px 수준으로 통일하면 가독성이 좋아집니다.
# 3. **투명도 조절로 중복 방지**
#    - 마커가 많을 경우 `fill_opacity=0.5`처럼 반투명하게 설정하면 시각적으로 깔끔합니다.
# 4. **범례(Legend)**
#    - Folium은 기본적으로 범례 기능이 없지만, HTML을 삽입하여 직접 만들 수 있습니다.
# 5. **확대/축소 제어 버튼 추가**
#    - `zoom_control=True`로 설정 시 사용자 조작이 가능합니다.
# ---

# %%
# 🌈 Folium DivIcon 스타일링 심화
import folium

# 중심 좌표
loc = [37.57, 126.98]
map6 = folium.Map(location=loc, zoom_start=14)

# 다양한 스타일을 가진 라벨 생성
html_label = '''
<div style="
    font-size:20px;
    font-weight:bold;
    color:#ffffff;
    background-color:rgba(0, 100, 255, 0.7);
    border: 2px solid #ffffff;
    border-radius: 10px;
    padding: 6px;
    text-align:center;
    width:140px;">
데이터사이언스관
</div>
'''

folium.Marker(
    location=loc,
    icon=folium.DivIcon(html=html_label)
).add_to(map6)

print("고급 스타일 라벨 추가 완료! (배경색, 테두리, 글씨 크기 포함)")
map6
# Out:
# 고급 스타일 라벨 추가 완료! (배경색, 테두리, 글씨 크기 포함)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a3c15c75163a6d9951a0a9bc2562211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a3c15c75163a6d9951a0a9bc2562211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a3c15c75163a6d9951a0a9bc2562211 = L.map(
#                 &quot;map_6a3c15c75163a6d9951a0a9bc2562211&quot;,
#                 {
#                     center: [37.57, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_749f25987e4e048b4ffc7bb3bac7a037 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_749f25987e4e048b4ffc7bb3bac7a037.addTo(map_6a3c15c75163a6d9951a0a9bc2562211);
#
#
#             var marker_3b703f1258477226e165c75b7727377f = L.marker(
#                 [37.57, 126.98],
#                 {
# }
#             ).addTo(map_6a3c15c75163a6d9951a0a9bc2562211);
#
#
#             var div_icon_abd29ec305e2009d1b9aa597ed3cddb3 = L.divIcon({
#   &quot;html&quot;: &quot;\n\u003cdiv style=\&quot;\n    font-size:20px;\n    font-weight:bold;\n    color:#ffffff;\n    background-color:rgba(0, 100, 255, 0.7);\n    border: 2px solid #ffffff;\n    border-radius: 10px;\n    padding: 6px;\n    text-align:center;\n    width:140px;\&quot;\u003e\n\ub370\uc774\ud130\uc0ac\uc774\uc5b8\uc2a4\uad00\n\u003c/div\u003e\n&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_3b703f1258477226e165c75b7727377f.setIcon(div_icon_abd29ec305e2009d1b9aa597ed3cddb3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 🎯 퀴즈: 덕성여자대학교 지도 표시하기 (기초)
#
# 지금까지 배운 Folium 기본기를 활용해 아주 간단한 문제를 풀어보세요! 🌸
#
# ---
#
# ## 🧭 문제
# 아래 조건에 따라 **덕성여자대학교**를 지도 위에 표시하세요.
#
# 1. 중심 좌표는 덕성여자대학교로 설정합니다.
#    - 위도(`lat`) = 37.6525
#    - 경도(`lon`) = 127.0165
# 2. `zoom_start`는 **16**으로 지정합니다.
# 3. 마커(`folium.Marker`)를 이용해 지도 위에
#    `덕성여자대학교` 라는 문구를 표시하세요.
# 4. 마지막 줄에 “지도 완성!”을 출력하세요.
#
# ---
#
# ## 💡 힌트
# - `folium.Map(location=[위도, 경도], zoom_start=16)`
# - `folium.Marker(location=[위도, 경도], popup="덕성여자대학교").add_to(map)`
# - `map`을 실행하면 지도가 표시됩니다.
#
# ---
#
# 🧠 **보너스 도전**
# - 마커 색상을 `pink`로 바꿔보세요.
# - 클릭 시 영어 이름 `"Duksung Women's University"` 가 보이도록 설정해보세요.
#
# ---
#
# 🎯 출력 예시
# - 지도 위에 덕성여자대학교 마커가 나타나면 성공입니다!
# - 지도 상단에 “지도 완성!”이 출력되어야 합니다.

# %%
import folium

# 덕성여자대학교 중심 좌표
loc = [37.6525, 127.0165]

# 지도 생성
map_ds = folium.Map(location=loc, zoom_start=16)

# 마커 추가
folium.Marker(
    location=loc,
    popup="덕성여자대학교",
    icon=folium.Icon(color='pink', icon='university', prefix='fa')
).add_to(map_ds)

print("지도 완성!")
map_ds

# %%
# 내가 푼 코드.
# 필수 패키지 설치(이 코드셀만 실행하는 경우를 위해.)
# !pip install folium geokakao pandas --quiet

# 라이브러리 불러오기
import folium
import geokakao as gk
import pandas as pd

# 1.
loc = [37.6525, 127.0165]
map = folium.Map(location=loc, zoom_start=16)
folium.Marker(location=loc, popup="덕성여자대학교").add_to(map)

# 보너스 도전. 마커 색상 변경, 클릭 시 영어 이름 "Duksung Women's University"
folium.Marker(
    location=loc,
    popup="Duksung Women's University",
    icon=folium.Icon(color="pink", icon="university", prefix="fa")
).add_to(map)

print("지도 완성!")
map
# Out:
# 지도 완성!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cebf6d1f506285c5f7b07d4312da525 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cebf6d1f506285c5f7b07d4312da525&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cebf6d1f506285c5f7b07d4312da525 = L.map(
#                 &quot;map_1cebf6d1f506285c5f7b07d4312da525&quot;,
#                 {
#                     center: [37.6525, 127.0165],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fed44a2fcd9a6decf40e17f43360443e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fed44a2fcd9a6decf40e17f43360443e.addTo(map_1cebf6d1f506285c5f7b07d4312da525);
#
#
#             var marker_54441a3faaf8aeb0d29960c5c0553d5c = L.marker(
#                 [37.6525, 127.0165],
#                 {
# }
#             ).addTo(map_1cebf6d1f506285c5f7b07d4312da525);
#
#
#         var popup_f9d725732c0b66b34b5b2643be50bbf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9248393aed6b3829eabc6b73f86e9394 = $(`&lt;div id=&quot;html_9248393aed6b3829eabc6b73f86e9394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕성여자대학교&lt;/div&gt;`)[0];
#                 popup_f9d725732c0b66b34b5b2643be50bbf4.setContent(html_9248393aed6b3829eabc6b73f86e9394);
#
#
#
#         marker_54441a3faaf8aeb0d29960c5c0553d5c.bindPopup(popup_f9d725732c0b66b34b5b2643be50bbf4)
#         ;
#
#
#
#
#             var marker_1e41f6771cbbab4fff247b7714e92674 = L.marker(
#                 [37.6525, 127.0165],
#                 {
# }
#             ).addTo(map_1cebf6d1f506285c5f7b07d4312da525);
#
#
#             var icon_e202ccdb00ed2f8f67aa92a1b2b4f84a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;pink&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6a358ef1fcc158244c77e46dd981b5c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bcb67b22281b76f14c57ce8a5e8bfa0 = $(`&lt;div id=&quot;html_8bcb67b22281b76f14c57ce8a5e8bfa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Duksung Women&#x27;s University&lt;/div&gt;`)[0];
#                 popup_6a358ef1fcc158244c77e46dd981b5c9.setContent(html_8bcb67b22281b76f14c57ce8a5e8bfa0);
#
#
#
#         marker_1e41f6771cbbab4fff247b7714e92674.bindPopup(popup_6a358ef1fcc158244c77e46dd981b5c9)
#         ;
#
#
#
#
#                 marker_1e41f6771cbbab4fff247b7714e92674.setIcon(icon_e202ccdb00ed2f8f67aa92a1b2b4f84a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
